# %%
import pandas as pd

#We will use numpy to calculate lograthims
import numpy as np

#We will use seaborn and matplotlib for plotting
import seaborn as sns
from matplotlib import pyplot as plt

###NOTE - you will probably get an error saying package seaborn not found. So you need to install it!
###How do you install packages???? After you install, refresh this page and try loading it again.

#This line will allow our plots to show in this notebook
# %matplotlib inline

# %% [markdown]
# Let's load up the clean dataframe that we made with filtered counts and our length column. We saved this file as a comma separated file (csv), so we will load it with read_csv (instead of read_table that is used for tab separated files). There aren't any comments at the top of the file, so we don't need to use comment = "#". Let's just set the first column as the index with index_col=0. Take a look at the shape and the first 5 rows of the dataframe.

# %%
feature_counts_dir = "/home/ucsd-train40/projects/mouse_LPS/featurecounts/"

counts = pd.read_csv(feature_counts_dir+"Mouse_LPS_clean_counts_with_length.csv", index_col=0)
print counts.shape
counts.head()
# Out:
# (16082, 5)
#                        Length  mouse_0hr_rep1  mouse_0hr_rep2  mouse_4hr_rep1  \
# Geneid
# ENSMUSG00000103922.1     1069               3               7               5
# ENSMUSG00000033845.13    8487             292             546             135
# ENSMUSG00000025903.14    7145             423             525             285
# ENSMUSG00000033813.15    3017             577             561             564
# ENSMUSG00000103280.1     1111              20               3               0
#
#                        mouse_4hr_rep2
# Geneid
# ENSMUSG00000103922.1                8
# ENSMUSG00000033845.13             175
# ENSMUSG00000025903.14             365
# ENSMUSG00000033813.15             483
# ENSMUSG00000103280.1                6

# %% [markdown]
# First lets make a list of the data columns and call them data_cols:

# %%
data_cols = counts.columns[1:]

# %% [markdown]
# Now take those data columns and divide them by the length in kilobases (length / 1000)

# %%
counts[data_cols].divide((counts['Length']/1000), axis=0)
# Out:
#                        mouse_0hr_rep1  mouse_0hr_rep2  mouse_4hr_rep1  \
# Geneid
# ENSMUSG00000103922.1         2.806361        6.548176        4.677268
# ENSMUSG00000033845.13       34.405561       64.333687       15.906681
# ENSMUSG00000025903.14       59.202239       73.477957       39.888034
# ENSMUSG00000033813.15      191.249586      185.946304      186.940670
# ENSMUSG00000103280.1        18.001800        2.700270        0.000000
# ENSMUSG00000033793.12      111.430330      145.187769      105.171352
# ENSMUSG00000025907.14      100.136147      102.722941       60.653506
# ENSMUSG00000090031.2        12.527634       21.923360       10.501105
# ENSMUSG00000103845.1         5.077263        1.986755       34.878587
# ENSMUSG00000033740.17       20.884901       33.106436       24.288366
# ENSMUSG00000051285.17       96.934175      112.714157      103.246168
# ENSMUSG00000103509.1        22.840119        8.937438       12.164846
# ENSMUSG00000061024.8       182.617188      372.558594      201.660156
# ENSMUSG00000025911.14       17.989418       25.925926       34.126984
# ENSMUSG00000079671.8         6.109980        3.054990        1.221996
# ENSMUSG00000025912.16       24.990744       23.880044        3.332099
# ENSMUSG00000045210.8       180.428762      186.172941      450.200021
# ENSMUSG00000097893.8         2.257336        0.322477        1.612383
# ENSMUSG00000025915.14       77.842219       74.418280      131.507232
# ENSMUSG00000103922.1         1.685882
# ENSMUSG00000033845.13        4.645139
# ENSMUSG00000025903.14       11.508150
# ENSMUSG00000033813.15       36.065064
# ENSMUSG00000103280.1         1.216612

# %%
#Now let's make a function out of this:

def counts_to_tpm(counts_matrix):
    data_cols = counts_matrix.columns[1:]
    rpk = counts_matrix[data_cols].divide((counts_matrix['Length']/1000), axis=0)
    sums_per_million = rpk.sum(axis=0)/(10**6)
    tpm = rpk.divide(sums_per_million)
    
    return tpm

# %%
tpm_from_function = counts_to_tpm(counts)

# %%
tpm.head()
# Out:
#                        mouse_0hr_rep1  mouse_0hr_rep2  mouse_4hr_rep1  \
# Geneid
# ENSMUSG00000103922.1         0.789101        1.043076        1.080166
# ENSMUSG00000033845.13        9.674258       10.247881        3.673479
# ENSMUSG00000025903.14       16.646662       11.704496        9.211718
# ENSMUSG00000033813.15       53.776128       29.619874       43.171966
# ENSMUSG00000103280.1         5.061800        0.430133        0.000000
#
#                        mouse_4hr_rep2
# Geneid
# ENSMUSG00000103922.1         1.685882
# ENSMUSG00000033845.13        4.645139
# ENSMUSG00000025903.14       11.508150
# ENSMUSG00000033813.15       36.065064
# ENSMUSG00000103280.1         1.216612

# %%
tpm.to_csv(feature_counts_dir+"Mouse_LPS_tpm.csv")

# %%
plt.hist(tpm['mouse_4hr_rep1'])
# Out:
# (array([  1.60540000e+04,   1.70000000e+01,   8.00000000e+00,
#           1.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00]),
#  array([     0.        ,   5846.0080235 ,  11692.016047  ,  17538.02407049,
#          23384.03209399,  29230.04011749,  35076.04814099,  40922.05616448,
#          46768.06418798,  52614.07221148,  58460.08023498]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.log2(tpm['mouse_4hr_rep1'] + 1))
# Out:
# (array([  4.97600000e+03,   4.12800000e+03,   3.42100000e+03,
#           2.14200000e+03,   9.23000000e+02,   3.53000000e+02,
#           8.30000000e+01,   3.10000000e+01,   2.20000000e+01,
#           3.00000000e+00]),
#  array([  0.        ,   1.58351889,   3.16703777,   4.75055666,
#           6.33407555,   7.91759443,   9.50111332,  11.08463221,
#          12.66815109,  14.25166998,  15.83518887]),
#  <a list of 10 Patch objects>)

# %%
sns.pairplot(np.log2(tpm+1))

# %%
log2_tpm = np.log2(tpm+1)

# %%
log2_tpm.corr()
# Out:
#                 mouse_0hr_rep1  mouse_0hr_rep2  mouse_4hr_rep1  mouse_4hr_rep2
# mouse_0hr_rep1        1.000000        0.945724        0.862081        0.860454
# mouse_0hr_rep2        0.945724        1.000000        0.862218        0.892849
# mouse_4hr_rep1        0.862081        0.862218        1.000000        0.961085
# mouse_4hr_rep2        0.860454        0.892849        0.961085        1.000000

# %%
sns.heatmap(log2_tpm.corr())

# %%
sns.lmplot('mouse_4hr_rep1','mouse_4hr_rep2',log2_tpm)

# %%
sns.lmplot('mouse_0hr_rep1','mouse_4hr_rep1',log2_tpm)

# %%
sns.lmplot('mouse_0hr_rep2','mouse_4hr_rep2',log2_tpm)
